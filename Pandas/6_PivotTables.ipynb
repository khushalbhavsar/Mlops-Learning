# %%
import numpy as np 
import pandas as pd

# %%
# Pivot Tables 

data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    393     38   John  January      Q1
# 1  2023-01-02       B   West    358     50   Mary  January      Q1
# 2  2023-01-03       C  North    994     88    Bob  January      Q1
# 3  2023-01-04       D  South    809     40  Alice  January      Q1
# 4  2023-01-05       A   East    872     15   John  January      Q1
# 5  2023-01-06       B   West    603     64   Mary  January      Q1
# 6  2023-01-07       C  North    674     97    Bob  January      Q1
# 7  2023-01-08       D  South    318     99  Alice  January      Q1
# 8  2023-01-09       A   East    185     71   John  January      Q1
# 9  2023-01-10       B   West    120     14   Mary  January      Q1
# 10 2023-01-11       C  North    658     93    Bob  January      Q1
# 11 2023-01-12       D  South    934     96  Alice  January      Q1
# 12 2023-01-13       A   East    436     61   John  January      Q1
# 13 2023-01-14       B   West    527     78   Mary  January      Q1
# 14 2023-01-15       C  North    946     69    Bob  January      Q1
# 15 2023-01-16       D  South    700     22  Alice  January      Q1
# 16 2023-01-17       A   East    930     62   John  January      Q1
# 17 2023-01-18       B   West    166     22   Mary  January      Q1
# 18 2023-01-19       C  North    666     19    Bob  January      Q1
# 19 2023-01-20       D  South    102     20  Alice  January      Q1

# %%
pd.pivot_table(df,values = "Sales",index = 'Region',columns="Product",aggfunc = 'median')
# Out:
# Product      A      B      C      D
# Region
# East     436.0    NaN    NaN    NaN
# North      NaN    NaN  674.0    NaN
# South      NaN    NaN    NaN  700.0
# West       NaN  358.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     563.2    NaN    NaN    NaN  49.4   NaN   NaN   NaN
# North      NaN    NaN  787.6    NaN   NaN   NaN  73.2   NaN
# South      NaN    NaN    NaN  572.6   NaN   NaN   NaN  55.4
# West       NaN  354.8    NaN    NaN   NaN  45.6   NaN   NaN

# %%
# Cross Tabs 
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
